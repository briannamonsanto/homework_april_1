# %%
import pandas as pd

# %%
accidents_df = pd.read_csv("accidents-nyc.csv")
accidents_df
# Out:
#        CRASH DATE CRASH TIME        BOROUGH  NUMBER OF PERSONS INJURED  \
# 0         4/13/21      21:35       BROOKLYN                          1
# 1         4/13/21      16:00       BROOKLYN                          0
# 2         4/13/21      17:30         QUEENS                          0
# 3         4/11/21      21:06       BROOKLYN                          1
# 4         4/15/21      20:00  STATEN ISLAND                          0
# ...           ...        ...            ...                        ...
# 282868     1/1/19      19:00       BROOKLYN                          0
# 282869     1/1/19       8:00          BRONX                          0
# 282870     1/1/19       3:30          BRONX                          0
# 282871     1/1/19      19:30       BROOKLYN                          0
# 282872     1/1/19      12:00      MANHATTAN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# ...

# %%
accidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282873 entries, 0 to 282872
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH DATE                     282873 non-null  object
#  1   CRASH TIME                     282873 non-null  object
#  2   BOROUGH                        282873 non-null  object
#  3   NUMBER OF PERSONS INJURED      282873 non-null  int64
#  4   NUMBER OF PERSONS KILLED       282873 non-null  int64
#  5   NUMBER OF PEDESTRIANS INJURED  282873 non-null  int64
#  6   NUMBER OF PEDESTRIANS KILLED   282873 non-null  int64
#  7   NUMBER OF CYCLIST INJURED      282873 non-null  int64
#  8   NUMBER OF CYCLIST KILLED       282873 non-null  int64
#  9   NUMBER OF MOTORIST INJURED     282873 non-null  int64
#  10  NUMBER OF MOTORIST KILLED      282873 non-null  int64
#  11  CONTRIBUTING FACTOR VEHICLE 1  281489 non-null  object
# ...

# %%
crashes=accidents_df["CRASH DATE"]
crashes
# Out:
# 0         4/13/21
# 1         4/13/21
# 2         4/13/21
# 3         4/11/21
# 4         4/15/21
#            ...
# 282868     1/1/19
# 282869     1/1/19
# 282870     1/1/19
# 282871     1/1/19
# 282872     1/1/19
# Name: CRASH DATE, Length: 282873, dtype: object

# %%
type(crashes)
# Out:
# pandas.core.series.Series

# %%
#### Which borough had the most crashes?
accidents_df["BOROUGH"].unique()
# Out:
# array(['BROOKLYN', 'QUEENS', 'STATEN ISLAND', 'BRONX', 'MANHATTAN'],
#       dtype=object)

# %%
bronx_fil = accidents_df["BOROUGH"] == "BRONX"
brooklyn_fil = accidents_df["BOROUGH"] == "BROOKLYN"
queens_fil = accidents_df["BOROUGH"] == "QUEENS"
manhattan_fil = accidents_df["BOROUGH"] == "MANHATTAN"
si_fil = accidents_df["BOROUGH"] == "STATEN ISLAND"

# %%
bronx_fil
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 282868    False
# 282869     True
# 282870     True
# 282871    False
# 282872    False
# Name: BOROUGH, Length: 282873, dtype: bool

# %%
accidents_df["BOROUGH"].value_counts()
# Out:
# BROOKLYN         95099
# QUEENS           80085
# BRONX            50123
# MANHATTAN        48864
# STATEN ISLAND     8702
# Name: BOROUGH, dtype: int64

# %%
##Brooklyn has the most crashes.

# %%
## which type of vehicle was primary vehicle involved in crashes?
## SHOW ONLY THE TOP 7

# %%
accidents_df["VEHICLE TYPE CODE 1"].value_counts(7)
print(f"Sedan, station wagon/sport utility vehicle, taxi, pick-up truck and box truck are the top 5 vehicles involved in crashes. the following are tied for 6th and 7th place: slingshot, chevy xpr, go kart, fdny engine, mac t")
# Out:
# Sedan, station wagon/sport utility vehicle, taxi, pick-up truck and box truck are the top 5 vehicles involved in crashes. the following are tied for 6th and 7th place: slingshot, chevy xpr, go kart, fdny engine, mac t

# %%
accidents_df["VEHICLE TYPE CODE 1"].unique()
# Out:
# array(['Sedan', 'Taxi', '�MBU', 'Station Wagon/Sport Utility Vehicle',
#        'Pick-up Truck', nan, 'Ambulance', 'Tow Truck / Wrecker', 'E-Bike',
#        'Van', 'Moped', 'Tractor Truck Diesel', 'AMBULANCE', 'Bike',
#        'Trailer', 'Bus', 'Box Truck', 'Motorcycle', 'Lift Boom',
#        'scooter', 'CATER', 'FDNY Ambul', '3-Door', 'SEMI TRAIL', 'Dump',
#        'Convertible', '4 dr sedan', 'dump', 'Flat Rack', 'Flat Bed',
#        'GARBAGE TR', 'Tanker', 'Carry All', 'Armored Truck',
#        'Garbage or Refuse', 'SCHOOL BUS', 'MOPED', 'Motorscooter',
#        'Concrete Mixer', 'Open Body', 'Beverage Truck', 'fire truck',
#        'E-Scooter', 'COMMERCIAL', 'PSD', 'MTA', 'PK', 'Minicycle', 'LIMO',
#        'Chassis Cab', 'Tractor Truck Gasoline', 'MACK',
#        'Refrigerated Van', 'van', 'Motorbike', 'Fire truck', 'TRUCK',
#        'ambulance', 'NYPD VAN', '2 dr sedan', 'Pallet', 'AMBULANE', 'AMB',
#        'EMS bus', 'FORKLIFT', 'SANMEN COU', 'FIRE TRUCK', 'forklift',
# ...

# %%
print(f"Five unusal vehicles to get into crashes are: E-scooter, UHAL, Forklift, Tanker and an E-bike")
# Out:
# Five unusal vehicles to get into crashes are: E-scooter, UHAL, Forklift, Tanker and an E-bike

# %%
## create a subset of data for only Queens
## place it in a dataframe called df_q

# %%
df_q= accidents_df[accidents_df["BOROUGH"] == "QUEENS"]
df_q
# Out:
#        CRASH DATE CRASH TIME BOROUGH  NUMBER OF PERSONS INJURED  \
# 2         4/13/21      17:30  QUEENS                          0
# 10        4/14/21      21:43  QUEENS                          0
# 17        4/15/21      14:30  QUEENS                          0
# 27        4/16/21      11:00  QUEENS                          1
# 28        4/16/21      17:00  QUEENS                          5
# ...           ...        ...     ...                        ...
# 282861     1/1/19      11:00  QUEENS                          0
# 282862     1/1/19      12:30  QUEENS                          0
# 282863     1/1/19       2:18  QUEENS                          0
# 282864     1/1/19      13:00  QUEENS                          0
# 282866     1/1/19      10:23  QUEENS                          1
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 2                              0                              0
# 10                             0                              0
# ...

# %%
df_q["NUMBER OF PERSONS KILLED"].value_counts()
# Out:
# 0    79972
# 1      107
# 2        5
# 3        1
# Name: NUMBER OF PERSONS KILLED, dtype: int64

# %%
107+ 10+ 3
# Out:
# 120

# %%
print(f" 120 people were killed in queens from these accidents")
# Out:
#  120 people were killed in queens from these accidents

# %%
df_q["NUMBER OF CYCLIST KILLED"].value_counts()
# Out:
# 0    80077
# 1        8
# Name: NUMBER OF CYCLIST KILLED, dtype: int64

# %%
print(f" 8 cyclists were killed in Queens")
# Out:
#  8 cyclists were killed in Queens

# %%
m_fil= accidents_df[accidents_df["BOROUGH"] == "MANHATTAN"]
taxi_fil=accidents_df[accidents_df["VEHICLE TYPE CODE 1"] == "Taxi"]

# %%
df_m= accidents_df[accidents_df["BOROUGH"] == "MANHATTAN"]
df_m
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  NUMBER OF PERSONS INJURED  \
# 15        4/16/21      21:20  MANHATTAN                          0
# 16        4/16/21      17:20  MANHATTAN                          0
# 39        4/16/21      20:55  MANHATTAN                          0
# 46        4/15/21      22:25  MANHATTAN                          1
# 47        4/14/21      10:09  MANHATTAN                          0
# ...           ...        ...        ...                        ...
# 282842     1/1/19      20:32  MANHATTAN                          0
# 282847     1/1/19       4:48  MANHATTAN                          0
# 282851     1/1/19       6:00  MANHATTAN                          0
# 282853     1/2/19       9:57  MANHATTAN                          0
# 282872     1/1/19      12:00  MANHATTAN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 15                             0                              0
# ...

# %%
taxi_m= df_m[df_m["VEHICLE TYPE CODE 1"] == "Taxi"]

# %%
taxi_m
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  NUMBER OF PERSONS INJURED  \
# 67        4/14/21       8:03  MANHATTAN                          1
# 144       4/14/21       0:42  MANHATTAN                          0
# 159       4/16/21      19:54  MANHATTAN                          0
# 283       4/16/21      21:04  MANHATTAN                          0
# 326       4/16/21      16:15  MANHATTAN                          0
# ...           ...        ...        ...                        ...
# 282632     1/1/19       1:30  MANHATTAN                          0
# 282684     1/1/19      16:00  MANHATTAN                          2
# 282802     1/1/19      16:15  MANHATTAN                          0
# 282819     1/1/19      20:30  MANHATTAN                          0
# 282851     1/1/19       6:00  MANHATTAN                          0
#
#         NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# 67                             0                              1
# ...

# %%
accidents_df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().head()
# Out:
# Unspecified                       78494
# Driver Inattention/Distraction    70615
# Failure to Yield Right-of-Way     20691
# Following Too Closely             14407
# Backing Unsafely                  13348
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
print(f"the top five causes of accidents in all boroughs are listed above")
# Out:
# the top five causes of accidents in all boroughs are listed above

# %%
accidents_df["CONTRIBUTING FACTOR VEHICLE 2"].value_counts().head()
# Out:
# Unspecified                       190456
# Driver Inattention/Distraction     14186
# Other Vehicular                     3529
# Failure to Yield Right-of-Way       2233
# Passing or Lane Usage Improper      2171
# Name: CONTRIBUTING FACTOR VEHICLE 2, dtype: int64

# %%
print(f"The primary cause of accidents in all boroughs (from secondary vehicles) is listed above")
# Out:
# The primary cause of accidents in all boroughs (from secondary vehicles) is listed above

# %%
## What were the 5 RAREST causes for primary vehicles causing the accident

accidents_df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().tail()
# Out:
# Shoulders Defective/Improper    13
# Texting                          8
# Cell Phone (hands-free)          8
# Windshield Inadequate            3
# Listening/Using Headphones       2
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
print(f" The five rarest causes for primary vehicles to cause accidents is listed above.")
# Out:
#  The five rarest causes for primary vehicles to cause accidents is listed above.

# %%
accidents_df["CONTRIBUTING FACTOR VEHICLE 1"].unique()
# Out:
# array(['Unspecified', 'Following Too Closely',
#        'Driver Inattention/Distraction', 'Passing Too Closely',
#        'Passing or Lane Usage Improper', 'Driver Inexperience',
#        'Failure to Yield Right-of-Way', 'Turning Improperly',
#        'Unsafe Speed', 'Backing Unsafely', 'Steering Failure',
#        'Traffic Control Disregarded', 'Drugs (illegal)',
#        'Reaction to Uninvolved Vehicle', 'View Obstructed/Limited',
#        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#        'Alcohol Involvement', 'Pavement Slippery', 'Brakes Defective',
#        'Oversized Vehicle', 'Animals Action', 'Unsafe Lane Changing',
#        'Outside Car Distraction', 'Illnes', 'Other Vehicular',
#        'Aggressive Driving/Road Rage', 'Fell Asleep',
#        'Tire Failure/Inadequate', 'Pavement Defective', nan,
#        'Lost Consciousness', 'Accelerator Defective',
#        'Passenger Distraction', 'Glare', 'Eating or Drinking',
# ...

# %%
print(f"Some unusual causes of accidents include falling asleep,falling debris and animal action")
# Out:
# Some unusual causes of accidents include falling asleep,falling debris and animal action
